# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, classification_report, confusion_matrix

# %% [markdown]
# ### Prueba de uso del pipeline creado por el grupo FONTANEROS

# %% [markdown]
# * El notebook `<nombre_grupo>_Pipelines_II.ipynb` que contenga el código comentado que permita cargar el modelo entrenado desde el directorio `/src/models` y realizar predicciones sobre el fichero `<nombre_dataset>_test.csv`, así como calcular las métricas de evaluación a vuestra elección y la justificación de las mismas.

# %%
'''
CARGA LOS DATASETS DE TRAIN Y TEST DESDE SU LOCALIZACIÓN EN `/src/data/`
El trainset será introducido en el pipeline y el testset será utilizado para comprobar los resultados
'''
trainset_vinos= pd.read_csv("../data/wines_train.csv")
testset_vinos= pd.read_csv("../data/wines_test.csv")
print(trainset_vinos.shape)
print(testset_vinos.shape)
trainset_vinos
# Out:
# (5197, 13)
# (1300, 13)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.9              0.18         0.40            2.20      0.049
# 1               7.1              0.18         0.74           15.60      0.044
# 2               7.6              0.51         0.24            1.20      0.040
# 3               6.0              0.25         0.28            7.70      0.053
# 4               9.0              0.38         0.41            2.40      0.103
# ...             ...               ...          ...             ...        ...
# 5192            6.4              0.24         0.50           11.60      0.047
# 5193            6.6              0.22         0.28           12.05      0.058
# 5194            6.6              0.20         0.38            7.90      0.052
# 5195            7.3              0.41         0.29            1.80      0.032
# 5196            5.9              0.18         0.28            5.10      0.039
#
# ...

# %%
'''
CARGA EL MODELO DESDE SU LOCALIZACIÓN EN `/src/models`
'''

# %%
'''

'''
